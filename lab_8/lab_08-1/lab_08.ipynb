# %% [markdown]
# # Intro to Natural Language Processing (NLP)
#
# The Natural Language Processing (NLP) field is incredibly vast, and it has applications in virtually every aspect of data science. In this notebook, we will walk through a **very brief** survey of NLP, and provide some instruction on a couple handy tools along the way.
#
# NLP tools span a wide range of implementations, and it is not uncommon for NLP packages to have conflicts with other Python libraries. So, to keep everything compatible in one place, it is recommended that you create a new pip environment for NLP projects. To set up an NLP pip environment for this lab, follow the steps in the "Pip Environment" section of the [Python Environment Setup page in Canvas](https://iu.instructure.com/courses/2181786/pages/week-1-%7C-python-environment-setup?module_item_id=30340853), and **use the *environment.yml* file provided in this folder.** This should install the packages you'll need for this lab.
#
# Next, **[download a spaCy NLP model](https://spacy.io/models)** based on your preferences (in the NLP environment) so you can use the spaCy library installed in the environment.
#
# *Optionally, if you prefer to use a different environment, install the following packages separately using pip: [Scikit-Learn](https://scikit-learn.org/stable/install.html#installing-the-latest-release), [spaCy](https://spacy.io/usage), [ScatterText](https://github.com/JasonKessler/scattertext#installation), [CorEx](https://ryanjgallagher.github.io/code/corex/example), and [vaderSentiment](https://github.com/cjhutto/vaderSentiment#installation).*

# %% [markdown]
# ## Preprocessing
#
# To illustrate preprocessing text data, we'll use the [spaCy](https://spacy.io/) package.
#
# *spaCy is capable of **much** more than what we will use it for in this lab. More advanced implementations of spaCy may require knowledge outside the scope of this course.*

# %%
import pandas as pd
import spacy
from spacy import displacy
print(spacy.__version__)
# Out:
# 3.7.4

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('whitegrid')
# %config InlineBackend.figure_formats = ['svg']

# %% [markdown]
# ### Tokenizing
#
# The very first part of dealing with text data is to collect each **term** or unitary element of text (e.g., words, punctuation, etc.) in the form of "tokens".

# %%
# depends on your choice of spaCy model
nlp = spacy.load('en_core_web_sm')

# %%
intro = '''The Natural Language Processing (NLP) field is incredibly vast,
and it has applications in virtually every aspect of data science.
In this notebook, we will walk through a **very brief** survey of NLP,
and provide some instruction on a couple handy tools along the way.
'''

doc = nlp(intro)

# %%
print([t.text for t in doc])
# Out:
# ['The', 'Natural', 'Language', 'Processing', '(', 'NLP', ')', 'field', 'is', 'incredibly', 'vast', ',', '\n', 'and', 'it', 'has', 'applications', 'in', 'virtually', 'every', 'aspect', 'of', 'data', 'science', '.', '\n', 'In', 'this', 'notebook', ',', 'we', 'will', 'walk', 'through', 'a', '*', '*', 'very', 'brief', '*', '*', 'survey', 'of', 'NLP', ',', '\n', 'and', 'provide', 'some', 'instruction', 'on', 'a', 'couple', 'handy', 'tools', 'along', 'the', 'way', '.', '\n']

# %%
for i, sentence in enumerate(doc.sents):
    print(f"sentence {i+1}\n\n", sentence)
# Out:
# sentence 1
#
#  The Natural Language Processing (NLP) field is incredibly vast,
# and it has applications in virtually every aspect of data science.
#
# sentence 2
#
#  In this notebook, we will walk through a **very brief** survey of NLP,
# and provide some instruction on a couple handy tools along the way.

# %%
df_intro = []

for token in doc:
    df_intro.append([
        token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
        token.shape_, token.is_alpha, token.is_stop
    ])

# %%
df_intro = pd.DataFrame(columns=["text", "lemma_", "pos_", "tag_", "dep_", "shape_", "is_alpha", "is_stop"],
                        data=df_intro)

# %%
df_intro.sample(5)
# Out:
#          text     lemma_   pos_   tag_    dep_ shape_  is_alpha  is_stop
# 26         In         in    ADP     IN    prep     Xx      True     True
# 4           (          (  PUNCT  -LRB-   punct      (     False    False
# 21         of         of    ADP     IN    prep     xx      True     True
# 27       this       this    DET     DT     det   xxxx      True     True
# 18  virtually  virtually    ADV     RB  advmod   xxxx      True    False

# %% [markdown]
# What is a **stop word**?

# %%
df_intro[df_intro['is_stop']].sample(10)
# Out:
#      text lemma_   pos_ tag_      dep_ shape_  is_alpha  is_stop
# 42     of     of    ADP   IN      prep     xx      True     True
# 55  along  along    ADP   IN      prep   xxxx      True     True
# 8      is     be    AUX  VBZ      ROOT     xx      True     True
# 51      a      a    DET   DT  quantmod      x      True     True
# 46    and    and  CCONJ   CC        cc    xxx      True     True
# 48   some   some    DET   DT       det   xxxx      True     True
# 34      a      a    DET   DT       det      x      True     True
# 26     In     in    ADP   IN      prep     Xx      True     True
# 50     on     on    ADP   IN      prep     xx      True     True
# 21     of     of    ADP   IN      prep     xx      True     True

# %% [markdown]
# spaCy defines **lemmas** to be *"the base forms of words. For example, the lemma of `was` is `be`, and the lemma of `rats` is `rat`."*

# %%
t = nlp('running')[0]
t.lemma_
# Out:
# 'run'

# %% [markdown]
# **Sentence Dependencies**

# %% [markdown]
# We can visualize some of these attributes (like the sentence dependencies) using [displacy](https://spacy.io/usage/visualizers).

# %%
doc = nlp('We can visualize these using displacy.')

# %%
displacy.render(doc, style='dep', options={'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="927f8ec529a749e1a07807102cf853a1-0" class="displacy" width="770" height="317.0" direction="ltr" style="max-width: none; height: 317.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">We</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">can</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">visualize</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">these</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">using</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">displacy.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-927f8ec529a749e1a07807102cf853a1-0-0" stroke-width="2px" d="M70,182.0 C70,62.0 285.0,62.0 285.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-927f8ec529a749e1a07807102cf853a1-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,184.0 L62,172.0 78,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-927f8ec529a749e1a07807102cf853a1-0-1" stroke-width="2px" d="M190,182.0 C190,122.0 280.0,122.0 280.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-927f8ec529a749e1a07807102cf853a1-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M190,184.0 L182,172.0 198,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-927f8ec529a749e1a07807102cf853a1-0-2" stroke-width="2px" d="M430,182.0 C430,62.0 645.0,62.0 645.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-927f8ec529a749e1a07807102cf853a1-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M430,184.0 L422,172.0 438,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-927f8ec529a749e1a07807102cf853a1-0-3" stroke-width="2px" d="M550,182.0 C550,122.0 640.0,122.0 640.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-927f8ec529a749e1a07807102cf853a1-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M550,184.0 L542,172.0 558,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-927f8ec529a749e1a07807102cf853a1-0-4" stroke-width="2px" d="M310,182.0 C310,2.0 650.0,2.0 650.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-927f8ec529a749e1a07807102cf853a1-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M650.0,184.0 L658.0,172.0 642.0,172.0" fill="currentColor"/>
# </g>
# </svg></span>

# %% [markdown]
# Note: this isn't always going to be *exactly* accurate, but it's very good and still useful.

# %% [markdown]
# ### Named Entity Recognition
#
# Some words are **Named Entities**: locations like "Alaska", dates like "January 1st", companies like "Google", etc. spaCy can tag these using [Named Entity Recognition](https://spacy.io/usage/linguistic-features#named-entities).

# %%
doc = nlp('... locations like "Alaska", dates like "January 1st", companies like "Google", etc.')

# %%
displacy.render(doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">... locations like &quot;
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alaska
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# &quot;, dates like &quot;
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     January 1st
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# &quot;, companies like &quot;
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Google
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# &quot;, etc.</div></span>

# %% [markdown]
# ### Multiple Documents
#
# *NLP Terms: A **document** is a collection of **tokens**, and a **corpus** is a collection of documents.*
#
# When spaCy processes text, it runs it through a [pipeline](https://spacy.io/usage/processing-pipelines) of different models to store token attributes for each token. This is how we get the functionality above. Though, when we are tokenizing multiple documents, we might not need all of these [built-in components](https://spacy.io/usage/processing-pipelines#built-in). For example, we might just need enough to filter our text based on the analysis done.
#
# For example, suppose we've determined that we want to the remove the following tokens from a dataset of [coffee reviews](https://www.kaggle.com/datasets/schmoyote/coffee-reviews-dataset/) (descriptions):
#
# - stop words (except the lemma "not", to maintain the idea of object negation)
# - punctuation
# - numbers
#
# In this case, we don't need NER, Dependency Labels, or Document Labels. Removing these processes from the spaCy pipeline will save us some time.

# %%
df_coffee = pd.read_csv('./data/coffee_analysis.csv')

# %%
df_coffee.drop_duplicates(subset='desc_1', inplace=True)

# %%
df_coffee.shape
# Out:
# (2092, 12)

# %%
print(df_coffee['desc_1'].sample().iloc[0])
# Out:
# Richly sweet, cocoa- and spice-toned. Dark chocolate, gently scorched sandalwood, orange zest, cinnamon, gardenia in aroma and cup. Sweet-tart structure with mild, rounded acidity; satiny mouthfeel. Spice-toned and chocolaty in the finish.

# %%
# nlp.pipe returns a generator
docs = nlp.pipe(df_coffee['desc_1'], disable=['ner', 'parser', 'textcat'])

# save the spaCy objects into the DataFrame
df_coffee['spacy_doc'] = list(docs)

# %%
def tokenizer(doc, join_tokens=False):
    '''
    Tokenize a single spaCy `doc`.

    join_tokens : bool
        Whether we want to return a list of strings or
        a list of lists. If True, join with space (" ").
    '''

    # collect lemmas that meet the following criteria:
    tokens = [w.lemma_.lower() for w in doc if
              (not w.is_stop
               and not w.is_punct
               and not w.like_num) \
              or (w.lemma_ == 'not')]

    if join_tokens:
        return ' '.join(tokens)
    else:
        return tokens

# %%
df_coffee['docs_clean'] = df_coffee['spacy_doc'].apply(tokenizer)

# %%
df_coffee[['desc_1', 'spacy_doc', 'docs_clean']].head()
# Out:
#                                               desc_1  \
# 0  Evaluated as espresso. Sweet-toned, deeply ric...
# 1  Evaluated as espresso. Sweetly tart, floral-to...
# 2  Crisply sweet, cocoa-toned. Lemon blossom, roa...
# 3  Delicate, sweetly spice-toned. Pink peppercorn...
# 4  Deeply sweet, subtly pungent. Honey, pear, tan...
#
#                                            spacy_doc  \
# 0  (Evaluated, as, espresso, ., Sweet, -, toned, ...
# 1  (Evaluated, as, espresso, ., Sweetly, tart, ,,...
# 2  (Crisply, sweet, ,, cocoa, -, toned, ., Lemon,...
# 3  (Delicate, ,, sweetly, spice, -, toned, ., Pin...
# 4  (Deeply, sweet, ,, subtly, pungent, ., Honey, ...
#
#                                           docs_clean
# 0  [evaluate, espresso, sweet, tone, deeply, rich...
# 1  [evaluate, espresso, sweetly, tart, floral, to...
# 2  [crisply, sweet, cocoa, tone, lemon, blossom, ...
# 3  [delicate, sweetly, spice, tone, pink, pepperc...
# 4  [deeply, sweet, subtly, pungent, honey, pear, ...

# %%
print(df_coffee['desc_1'].iloc[5])
# Out:
# Delicate, richly and sweetly tart. Dried hibiscus, fine musk, almond, sandalwood, raspberry in aroma and cup. Fruit-toned, deeply sweet structure with gently-expressed acidity; buoyant, satiny-smooth mouthfeel. The crisp, flavor-saturated finish is characterized by sweet-tart fruit and floral tones (raspberry, hibiscus).

# %%
print(df_coffee['docs_clean'].iloc[5])
# Out:
# ['delicate', 'richly', 'sweetly', 'tart', 'dry', 'hibiscus', 'fine', 'musk', 'almond', 'sandalwood', 'raspberry', 'aroma', 'cup', 'fruit', 'tone', 'deeply', 'sweet', 'structure', 'gently', 'express', 'acidity', 'buoyant', 'satiny', 'smooth', 'mouthfeel', 'crisp', 'flavor', 'saturate', 'finish', 'characterize', 'sweet', 'tart', 'fruit', 'floral', 'tone', 'raspberry', 'hibiscus']

# %% [markdown]
# ## Vectorization
#
# Once we have our tokens selected and "cleaned", we need to convert the textual data into numerical data. **In other words, we need to convert each token (or document) into a *vector* representation.** There are many ways to represent textual information in the form of numerical data, but in this class we will cover Count Vectorization and Term-Frequency Inverse Document Frequency Vectorization; we'll call these **vectorizers**.

# %% [markdown]
# ### Brief Intro to Scikit-Learn
#
# **[Scikit-Learn](https://scikit-learn.org/stable/index.html) is the industry standard data science toolkit**, and it's modules are used in almost every aspect of data science. Here, we are going to use its [feature extraction module](https://scikit-learn.org/stable/modules/feature_extraction.html), which is built for extracting numerical features from data such as text or images. We will be using it for vectorization of text data, and in these cases, the scikit-learn process is:
#
# 1. Preprocess some data (e.g., from text to tokens)
# 2. Define a model (e.g., a vectorizer)
# 3. "Fit" that model to the data using `.fit`
# 4. Transform the data based on the model's parameters using `.transform`
#     - We can also combine these last two steps with `.fit_transform`

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# %% [markdown]
# ### CountVectorizer
#
# CountVectorizer converts each document into a "Bag of Words". In other words, the document is encoded based on the words it contains, **regardless of the order**. And, each term can be represented based on the documents it is contained in.

# %%
corpus_raw = ['This coffee is really really tasty.',
              'Tea smells and tastes better than coffee.',
              "Best smelling coffee I have ever smelled!"]

# %%
cv = CountVectorizer(ngram_range=(1, 1),  # capture "pairs", or "n-tuples" of adjacent words
                     max_df=1.0,          # exclude terms in ≥ `max_df` (or %) of docs
                     min_df=1,            # exclude terms in ≤ `min_df` (or %) of docs
                     max_features=None,   # maximum number of terms/ngrams to include
                     binary=False)        # only log 1s and 0s for term presence

X = cv.fit_transform(corpus_raw)

df = pd.DataFrame(X.toarray(),
                  index=corpus_raw,
                  columns=cv.get_feature_names_out())

# %%
plt.figure(figsize=(8, 1))
g = sns.heatmap(df, cmap='Blues', annot=True, cbar=False, linewidths=1)

# %% [markdown]
# This is called a **document-term matrix**.
#
# - We could use `max_df` to remove the term "coffee" since it occurs in every document. This is one example of extracting *informative* features from text; i.e., the term "coffee" doesn't provide new information for each document.
# - Also, we can already see that some of these words give us more information than others. For example, "smelling" and "smells" mean roughly the same thing, and "had"/"have" aren't really necessary for understanding reviews.
#
# This is why we use the filtering in spaCy.

# %%
docs = nlp.pipe(corpus_raw)
corpus_clean = [tokenizer(d, True) for d in docs]
corpus_clean
# Out:
# ['coffee tasty', 'tea smell taste well coffee', 'good smell coffee smell']

# %%
cv = CountVectorizer(ngram_range=(1, 1),
                     max_df=0.9,
                     min_df=1,
                     max_features=None,
                     binary=False)

X = cv.fit_transform(corpus_clean)

df = pd.DataFrame(X.toarray(),
                  index=corpus_raw,
                  columns=cv.get_feature_names_out())

# %%
plt.figure(figsize=(6, 1))
g = sns.heatmap(df, cmap='Blues', annot=True, cbar=False, linewidths=1)

# %%
cv = CountVectorizer(ngram_range=(2, 2),  # use (1, 2) for unigrams *and* bigrams
                     max_df=0.9,
                     min_df=1,
                     max_features=None,
                     binary=False)

X = cv.fit_transform(corpus_clean)

df = pd.DataFrame(X.toarray(),
                  index=corpus_clean,
                  columns=cv.get_feature_names_out())

# %%
plt.figure(figsize=(10, 1))
g = sns.heatmap(df, cmap='Blues', annot=True, cbar=False, linewidths=1)

# %% [markdown]
# Now these vectors are a bit more meaningful. Notice, in a way, bigrams are a contrived way to capture context in textual data.

# %% [markdown]
# ### TFIDF Vectorizer
#
# Downsides of Count Vectorizer:
#
# - Counts can be too simplistic
# - High counts can dominate, especially for high frequency words or long documents
# - Each word is treated equally, when some terms might be more "important" than others
#
# We define TFIDF as:
#
# $$
# \text{TF-IDF} = \text{term frequency} * \text{inverse document frequency}
# $$
#
# where:
#
# $$
# \begin{align*}
# \text{term frequency} &= \frac{\text{term count in document}}{\text{total terms in document}} \\[8pt]
# \text{inverse document frequency} &= \log\bigg(\frac{\text{total number of documents} + 1}{\text{number of documents with term} + 1}\bigg)
# \end{align*}
# $$

# %% [markdown]
# This measure is calculated for every term-document combination:
#
# - The **term frequency** measures the "density" of a word in a document
# - The **inverse document frequency** (without the $\log$) measures the size of the corpus *in terms of* the number of documents containing the term. E.g., if IDF=5 then the corpus is 5 times the size of the "sub-corpus" of documents containing the term. The $\log$ dampens the effect of the inverse document frequency as the denominator gets very small or the numerator gets very large.
#
# So, we can think of TF as the "main" measure, and IDF as the "scaling" factor:
#
# - Very common words across all documents will get a lower score.
# - Rare words considering all documents get a higher score.

# %%
cv = TfidfVectorizer(max_df=1.0,
                     min_df=1,
                     max_features=None)

X = cv.fit_transform(corpus_clean)

df = pd.DataFrame(X.toarray(),
                  index=corpus_clean,
                  columns=cv.get_feature_names_out())

# %%
sns.heatmap(df, square=True, cmap='Blues', annot=True, cbar=False);

# %% [markdown]
# ## Topic Modeling
#
# ### Matrix Decomposition
#
# The document term matrix $X$ is a matrix just like any other in Linear Algebra. Just so, it defines a row space (the documents represented as linear combinations of terms), and column space (terms represented as a linear combination of documents). With this, there are a few matrix decomposition methods we can use to extract further information about these documents and terms.

# %%
from sklearn.decomposition import TruncatedSVD, NMF, PCA

# %% [markdown]
# ### Singular Value Decomposition
#
# Singular Value Decomposition is a guaranteed decomposition for any rectangular matrix. It creates the following equality:
#
# $$
# X = U\Sigma V^\top
# $$
#
# **Breifly**:
# - Each row of $U$ represents the corresponding document in terms of "topics directions" along the columns.
# - The rows of $V$ (columns of $V^\top$) represent similarly represented version of the terms.
# - The $\Sigma$ matrix contains the "variance explained" by each of these topics, sorted in descending order.
#
# As far as naming goes:
#
# - The analysis of these resulting matrices is called **Principal Components Analysis (PCA)**.
# - When used with text data, this analysis is called **Latent Semantic Analysis (LSA)**.

# %%
# we need a list/array of strings to vectorize
corpus = df_coffee['spacy_doc'].apply(tokenizer, args={'join_tokens':True})

# %%
corpus
# Out:
# 0       evaluate espresso sweet tone deeply rich choco...
# 1       evaluate espresso sweetly tart floral tone hon...
# 2       crisply sweet cocoa tone lemon blossom roasted...
# 3       delicate sweetly spice tone pink peppercorn da...
# 4       deeply sweet subtly pungent honey pear tangeri...
#                               ...
# 2090    crisply sweet nut tone almond brittle pie cher...
# 2091    chocolaty floral framed cocoa nib honeysuckle ...
# 2092    high tone enticingly sweet black cherry narcis...
# 2093      vibrantly sweet subtly nuance apricot dark c...
# 2094    evaluate espresso multi layered complex dark c...
# Name: spacy_doc, Length: 2092, dtype: object

# %%
cv = TfidfVectorizer(max_df=0.9,
                     min_df=0.1,
                     max_features=None)

X = cv.fit_transform(corpus)
# df = pd.DataFrame(X, index=corpus, columns=cv.get_feature_names_out())

# %%
# X.shape
print(X)
# Out:
#   (0, 9)	0.26068737420054117
#   (0, 10)	0.20000936405416708
#   (0, 16)	0.17471418012957365
#   (0, 18)	0.18990898315341884
#   (0, 21)	0.22559494129795052
#   (0, 22)	0.22559494129795052
#   (0, 23)	0.21957225670867275
#   (0, 24)	0.18027609262980343
#   (0, 37)	0.17924660576961973
#   (0, 38)	0.22135405001467773
#   (0, 43)	0.21857297697966938
#   (0, 44)	0.20098179472809047
#   (0, 45)	0.41208967235316585
#   (0, 51)	0.24100082667850162
#   (0, 55)	0.08862873942600963
#   (0, 58)	0.1495534635589829
#   (0, 60)	0.30784207314132533
#   (0, 64)	0.34751713682586793
#   (1, 8)	0.18272015676288325
#   (1, 9)	0.22136499479356506
#   (1, 16)	0.148360094896628
#   (1, 20)	0.3242558985273664
#   (1, 21)	0.19156594430023516
#   (1, 22)	0.19156594430023516
#   (1, 24)	0.4592491266075039
#   :	:
#   (2090, 16)	0.24964394190231945
#   (2090, 30)	0.6651346456212938
#   (2090, 40)	0.1715494144586874
#   (2090, 53)	0.24133954315923192
#   (2090, 54)	0.13129285770005902
#   (2090, 55)	0.12663899323874844
#   (2090, 56)	0.2216783204283279
#   (2090, 58)	0.21369253566207652
#   (2090, 59)	0.20067863803591396
#   (2091, 6)	0.3009069855021576
#   (2091, 7)	0.2134139316815076
#   (2091, 9)	0.3308731926493225
#   (2091, 14)	0.24298507963982097
#   (2091, 16)	0.22175312002686495
#   (2091, 20)	0.24233186570707807
#   (2091, 21)	0.2863326952511628
#   (2091, 22)	0.2863326952511628
#   (2091, 24)	0.2288124866411127
#   (2091, 27)	0.2184966451363881
#   (2091, 30)	0.2954121012922418
#   (2091, 38)	0.2809500132441098
#   (2091, 40)	0.15238350109805834
#   (2091, 52)	0.2846173236380137
#   (2091, 58)	0.1898182913970295
#   (2091, 60)	0.1302411747460906

# %% [markdown]
# Note, we use `TruncatedSVD` here because it's a more efficient implementation of SVD. PCA centers the data before running the algorithm, which is more "appropriate" but takes more time. This does cause a few inconsistencies in the "sorted" $\Sigma$.

# %%
lsa = TruncatedSVD(n_components=5)  # results only change for larger (unseen) values

doc_topic = lsa.fit_transform(X)
lsa.explained_variance_ratio_
# Out:
# array([0.00488089, 0.08197357, 0.0477831 , 0.04678163, 0.03501969])

# %%
doc_topic = pd.DataFrame(doc_topic.round(3),
                         index=df_coffee['desc_1'])
doc_topic.head()
# Out:
#                                                         0      1      2  \
# desc_1
# Evaluated as espresso. Sweet-toned, deeply rich...  0.505 -0.283 -0.259
# Evaluated as espresso. Sweetly tart, floral-ton...  0.496 -0.268 -0.137
# Crisply sweet, cocoa-toned. Lemon blossom, roas...  0.561  0.319  0.050
# Delicate, sweetly spice-toned. Pink peppercorn,...  0.506  0.153  0.120
# Deeply sweet, subtly pungent. Honey, pear, tang...  0.469 -0.071 -0.308
#
#                                                         3      4
# desc_1
# Evaluated as espresso. Sweet-toned, deeply rich...  0.193  0.073
# Evaluated as espresso. Sweetly tart, floral-ton...  0.297  0.012
# Crisply sweet, cocoa-toned. Lemon blossom, roas...  0.036  0.172
# Delicate, sweetly spice-toned. Pink peppercorn,...  0.064 -0.052
# Deeply sweet, subtly pungent. Honey, pear, tang... -0.183 -0.014

# %%
topic = 1
n_docs = 5

print(f"Top Documents for topic {topic}:\n")

for doc in doc_topic[topic].abs().sort_values(ascending=False).iloc[:n_docs].index:
    print(doc, '\n')
# Out:
# Top Documents for topic 1:
#
# Sweetly floral and delicately cocoa-toned. Honeysuckle, cocoa nib, Concord grape, agave, lemon-thyme in aroma and cup. High-toned structure with juicy, confident acidity; buoyant, lively, viscous mouthfeel. Honeysuckle and cocoa nib characterize the sweet finish.
#
# Evaluated as espresso. Roast-rounded, chocolaty. Dark chocolate, gardenia, gently scorched cedar, molasses, prune in aroma and small cup. Viscous, creamy mouthfeel; chocolaty, slightly smoky finish. In three parts milk, floral and chocolate notes preside.
#
# Evaluated as espresso. Fruit-forward, chocolaty. Dark chocolate, black cherry, lily, molasses, cedar in aroma and small cup. Very syrupy mouthfeel; crisp, chocolaty finish. In three parts milk, dark chocolate notes take center stage, supported by notes of black cherry and lily.
#
# Evaluated as espresso. Bittersweet, richly pungent, chocolaty and floral. Dark chocolate, plum, cedar, magnolia in aroma and small cup. Plump, satiny mouthfeel; bittersweet and chocolaty in the finish. Chocolate and flowers dominate in three parts milk.
#
# Delicately sweet-tart, floral-toned. Narcissus, apricot, cocoa nib, lemon verbena, frankincense in aroma and cup. Sweet-tart structure with delicately juicy acidity; very full, syrupy mouthfeel. Cocoa nib and narcissus focus the long, lingering finish.

# %%
topic_term = pd.DataFrame(lsa.components_.round(3),
                          columns = cv.get_feature_names_out())

topic_term
# Out:
#    acidity  almond   bake  balanced  bright  brisk  butter  cedar  center  \
# 0    0.192   0.124  0.090     0.103   0.117  0.072   0.068  0.167   0.082
# 1    0.072  -0.025 -0.142     0.065   0.120 -0.019  -0.019 -0.107  -0.003
# 2    0.039   0.063  0.302    -0.045  -0.126  0.195   0.061  0.143  -0.007
# 3   -0.121   0.009 -0.111    -0.009   0.009 -0.086   0.032  0.066  -0.012
# 4   -0.086  -0.160 -0.130     0.011  -0.166 -0.034  -0.079 -0.085  -0.059
#
#    chocolate  ...  sweet  sweetly  syrup  syrupy   tart   tone  undertone  \
# 0      0.256  ...  0.280    0.146  0.079   0.144  0.195  0.249      0.077
# 1     -0.461  ...  0.034    0.029  0.041   0.038  0.113  0.032     -0.016
# 2     -0.070  ...  0.098   -0.059  0.058  -0.146 -0.108  0.111      0.058
# 3     -0.029  ... -0.173   -0.038 -0.046  -0.041  0.034  0.095      0.006
# 4     -0.078  ...  0.082   -0.138 -0.055   0.042 -0.369 -0.069      0.026
#
#    velvety  vibrant   zest
# 0    0.070    0.066  0.148
# 1   -0.046    0.070  0.040
# 2    0.125   -0.089  0.017
# 3   -0.016   -0.017  0.009
# 4    0.023   -0.053 -0.062
#
# [5 rows x 65 columns]

# %%
# the third "topic"
topic = 2
n_terms = 10

topic_term.T[topic].abs().sort_values(ascending=False).iloc[:n_terms]
# Out:
# bake          0.302
# sandalwood    0.263
# dark          0.254
# nut           0.238
# flavor        0.217
# savory        0.215
# juicy         0.205
# cut           0.201
# hazelnut      0.198
# brisk         0.195
# Name: 2, dtype: float64

# %% [markdown]
# ### Non-Negative Matrix Factorization
#
# [NMF](https://en.wikipedia.org/wiki/Non-negative_matrix_factorization) is very similar to SVD. Here, we have the following decomposition.
#
# $$
# X = WH
# $$
#
# In this case though, all values in $W$ and $H$ are positive, and we can *approximate* this decomposition because all values in $X$ are positive.

# %%
nmf = NMF(4)  # here, the number will change the results
doc_topic = nmf.fit_transform(X)

# %%
doc_topic = pd.DataFrame(doc_topic.round(3),
                         index=df_coffee['desc_1'])
# doc_topic.head()

# %%
topic = 1
n_docs = 5

print(f"Top Documents for topic {topic}:\n")

for doc in doc_topic[topic].abs().sort_values(ascending=False).iloc[:n_docs].index:
    print(doc, '\n')
# Out:
# Top Documents for topic 1:
#
# Evaluated as espresso. Fruit-forward, chocolaty. Dark chocolate, black cherry, lily, molasses, cedar in aroma and small cup. Very syrupy mouthfeel; crisp, chocolaty finish. In three parts milk, dark chocolate notes take center stage, supported by notes of black cherry and lily.
#
# Evaluated as espresso. Bittersweet, richly pungent, chocolaty and floral. Dark chocolate, plum, cedar, magnolia in aroma and small cup. Plump, satiny mouthfeel; bittersweet and chocolaty in the finish. Chocolate and flowers dominate in three parts milk.
#
# Evaluated as espresso. Deeply chocolaty, balanced, roast-rounded. Dark chocolate, nectarine, molasses, gently scorched cedar, rhododendron in aroma and small cup. Full, satiny mouthfeel; crisp, chocolaty finish. In three parts milk the dark chocolate notes are amplified, as are the florals
#
# Evaluated as espresso. Roast-rounded, chocolaty. Dark chocolate, gardenia, gently scorched cedar, molasses, prune in aroma and small cup. Viscous, creamy mouthfeel; chocolaty, slightly smoky finish. In three parts milk, floral and chocolate notes preside.
#
# Evaluated as espresso. Richly chocolaty, fruit-toned. Dark chocolate, raspberry jam, cedar, caramel, lemon verbena in aroma and small cup. Crisp, syrupy-smooth mouthfeel; chocolaty, sweetly herbaceous finish. In three parts milk, raspberry notes recede and caramel and chocolate come forward.

# %%
topic_term = pd.DataFrame(nmf.components_.round(3),
                          columns = cv.get_feature_names_out())

topic_term
# Out:
#    acidity  almond   bake  balanced  bright  brisk  butter  cedar  center  \
# 0    0.933   0.391  0.000     0.612   0.863  0.000   0.083  0.022   0.351
# 1    0.000   0.173  0.000     0.047   0.000  0.000   0.133  0.603   0.114
# 2    0.547   0.485  0.961     0.104   0.000  0.611   0.301  0.660   0.210
# 3    0.492   0.163  0.000     0.363   0.487  0.017   0.112  0.284   0.167
#
#    chocolate  ...  sweet  sweetly  syrup  syrupy   tart   tone  undertone  \
# 0      0.805  ...  1.422    0.898  0.233   1.221  0.997  0.601      0.091
# 1      1.579  ...  0.029    0.135  0.000   0.173  0.178  0.398      0.179
# 2      0.709  ...  0.897    0.238  0.294   0.032  0.199  0.702      0.276
# 3      0.000  ...  0.503    0.333  0.230   0.308  0.705  0.737      0.192
#
#    velvety  vibrant   zest
# 0    0.000    0.556  0.650
# 1    0.118    0.000  0.136
# 2    0.438    0.000  0.353
# 3    0.048    0.260  0.377
#
# [4 rows x 65 columns]

# %%
topic = 0
n_terms = 10

topic_term.T[topic].sort_values(ascending=False).iloc[:n_terms]
# Out:
# savory        2.345
# sweet         1.422
# long          1.284
# flavor        1.231
# syrupy        1.221
# juicy         1.121
# sandalwood    1.120
# structure     1.107
# resonant      1.048
# richly        1.022
# Name: 0, dtype: float64

# %%
topic = 1
n_terms = 10

topic_term.T[topic].sort_values(ascending=False).iloc[:n_terms]
# Out:
# chocolate    1.579
# dark         1.304
# milk         1.131
# espresso     1.126
# evaluate     1.099
# small        1.097
# chocolaty    1.014
# cedar        0.603
# fruit        0.520
# floral       0.493
# Name: 1, dtype: float64

# %% [markdown]
# As you can tell, this often produces more agreeable results than LSA.

# %% [markdown]
# ### Latent Dirichlet Allocation (LDA)
#
# [LDA](https://scikit-learn.org/stable/modules/generated/sklearn.decomposition.LatentDirichletAllocation.html) is a "generative" model that builds topics with the assumption that documents are generated based on a probability distribution of topics, and that topics are just a probability distribution of terms.

# %%
from sklearn.decomposition import LatentDirichletAllocation

# %%
# these parameters usually require a good bit of tuning ...
lda = LatentDirichletAllocation(n_components=5,
                                max_iter=50)

X_topics = lda.fit_transform(X)

# %%
df_lda = pd.DataFrame(data = X_topics,
                      index = corpus)

# %%
topic = 0
n_docs = 3

for d in df_lda[topic].sort_values(ascending=False).iloc[:n_docs].index:
    print(d, '\n')
# Out:
# evaluate espresso deeply chocolaty richly floral chocolate fudge lilac peach fresh cut cedar hazelnut butter aroma small cup crisp satiny smooth mouthfeel deep long resonant finish maintain aroma flavor note cup profoundly satisfy part milk chocolate floral slow dance fruit return surface long finish
#
# evaluate espresso crisply sweet richly floral tone lavender dark chocolate red currant almond butter pink grapefruit zest aroma small cup delicate viscous mouthfeel richly dry finish center note tart fruit dark chocolate bittersweet lavender like flower chocolaty floral part milk ongoing tart fruit note
#
# evaluate espresso deeply sweetly nut tone almond butter magnolia dark chocolate crisp pear fresh cut cedar aroma small cup viscous smooth mouthfeel crisply sweet tart finish cappuccino scale milk amplify magnolia dark chocolate note

# %%
topic = 1
n_docs = 3

for d in df_lda[topic].sort_values(ascending=False).iloc[:n_docs].index:
    print(d, '\n')
# Out:
# rich toned deeply sweetly earthy chocolate fudge white sage blackberry perique pipe tobacco plumeria like flower aroma cup balanced sweet savory structure vibrant juicy acidity delicate satiny mouthfeel resonant flavor saturate finish display note blackberry tobacco short plumeria sage long deep chocolate
#
# high tone sweetly tart deeply savory jasmine dark chocolate lemon verbena pink grapefruit zest candycap mushroom aroma cup balanced sweet tart savory structure lyrical syrupy smooth mouthfeel flavor saturate finish lead citrus note lemon verbena grapefruit short round deep chocolate sweet mushroom long
#
# crisply sweet spice tone dry papaya caramel tangerine zest pink peppercorn vanilla aroma cup high tone sweetly tart structure juicy bright acidity lean satiny smooth mouthfeel resonant richly dry finish laden sweet note caramel papaya short turn savory lean long hint pink peppercorn wrap vanilla

# %%
df_lda_terms = pd.DataFrame(data = lda.components_,
                            columns = cv.get_feature_names_out())

# %%
topic = 0
n_terms = 10

df_lda_terms.T[topic].sort_values(ascending=False).iloc[:n_terms]
# Out:
# milk         74.434873
# espresso     69.640880
# small        69.544897
# evaluate     67.766348
# chocolate    56.228779
# chocolaty    38.007117
# dark         34.632009
# cedar        27.733566
# floral       26.608576
# tone         26.556698
# Name: 0, dtype: float64

# %%
topic = 1
n_terms = 10

df_lda_terms.T[topic].sort_values(ascending=False).iloc[:n_terms]
# Out:
# sandalwood    66.198787
# chocolate     64.471390
# dark          62.016484
# juicy         59.960174
# savory        59.350198
# sweet         57.611484
# syrupy        51.583477
# tart          50.511120
# flavor        49.564558
# acidity       47.211431
# Name: 1, dtype: float64

# %% [markdown]
# ### Anchored Correlation Explanation (CorEx)
#
# [CorEx](https://github.com/gregversteeg/corex_topic) is a discriminative model, which starts from $X$ (documents/words) to determine $Y$ (topics). CorEx looks for groups of words that are in the same topic, a.k.a. have high Total Correlation (TC), or convey the same information.
#
# - If words are **tightly related** (always appear together in the same topic/document), TC will be high. This is a good topic.
# - If the words are all **independent** (never appear together in the same document or topic), TC = 0. This is a bad topic.
# - CorEx creates a partition across terms. I.e., **terms can only occur in a single topic**.
#
# CorEx roughly follows this algorithm:
# 1. Look for a group of words that are both as broad (in many documents) and overlapping as possible (both together will lead to high TC), and call this a topic.
# 2. Repeat the process for another set of words (not overlapping with your previous group) with as high a TC as possible, and call this the next topic.
#
# As we create more topics, each subsequent topic will have lower TC.

# %%
from corextopic import corextopic as ct

# %%
# CorEx requires count data
cv = CountVectorizer(max_df=0.9,
                     min_df=0.1,
                     max_features=None)

X = cv.fit_transform(corpus)

# %%
topic_model = ct.Corex(n_hidden=5,                        # number of topics
                       words=cv.get_feature_names_out(),  # list of terms in corpus
                       seed=1)

doc_topic = topic_model.fit_transform(X, words=cv.get_feature_names_out(), docs=corpus)

# %%
# Print all topics from the CorEx topic model
topics = topic_model.get_topics()

for n, topic in enumerate(topics):
    topic_words,_,_ = zip(*topic)
    print(f"{n}: " + ','.join(topic_words))
# Out:
# 0: espresso,evaluate,small,milk,structure,acidity,consolidate,floral,syrup,crisp
# 1: chocolate,dark,nib,cocoa,chocolaty,bake,delicate,lemon,deep,zest
# 2: juicy,cut,gentle,bright,fresh,sandalwood,brisk,tart,high,nut
# 3: short,long,lead,undertone,rich,center,almond
# 4: sweet,sweetly,savory,deeply,fruit,smooth

# %% [markdown]
# Take a look at how you can use [anchor words](https://github.com/gregversteeg/corex_topic/tree/master#using-anchor-words) to guide the topic creation.

# %% [markdown]
# ## ScatterText
#
# Scattertext is great for
# - Visually inspecting text
# - Comparing/Contrasting corpora
# - And more...
#
# Check out Jason Kessler's GitHub project for more information: [here](https://github.com/JasonKessler/scattertext).

# %%
import scattertext as st

# %%
convention_df = st.SampleCorpora.ConventionData2012.get_data()

# %%
convention_df.head()
# Out:
#       party                                               text         speaker
# 0  democrat  Thank you. Thank you. Thank you. Thank you so ...    BARACK OBAMA
# 1  democrat  Thank you so much. Tonight, I am so thrilled a...  MICHELLE OBAMA
# 2  democrat  Thank you. It is a singular honor to be here t...  RICHARD DURBIN
# 3  democrat  Hey, Delaware. \nAnd my favorite Democrat, Jil...    JOSEPH BIDEN
# 4  democrat  Hello. \nThank you, Angie. I'm so proud of how...      JILL BIDEN

# %%
corpus = st.CorpusFromPandas(convention_df,
                             category_col='party',
                             text_col='text',
                             nlp=st.whitespace_nlp_with_sentences
                            ).build()

# %%
html = st.produce_scattertext_explorer(
        corpus,
        category='democrat',
        category_name='Democratic',
        not_category_name='Republican',
        minimum_term_frequency=10,
        pmi_threshold_coefficient=5,
        width_in_pixels=1000,
        metadata=convention_df['speaker'],
        )

# %%
with open('demo.html', 'wb') as f:
    f.write(html.encode('utf-8'))

# %% [markdown]
# ## Sentiment Analysis with VADER
#
# According to the documentation:
#
#     VADER (Valence Aware Dictionary and sEntiment Reasoner) is a lexicon and rule-based sentiment analysis tool that is specifically attuned to sentiments expressed in social media. [...]
#
#     Sentiment ratings from 10 independent human raters (all pre-screened, trained, and quality checked for optimal inter-rater reliability). Over 9,000 token features were rated on a scale from "[–4] Extremely Negative" to "[4] Extremely Positive", with allowance for "[0] Neutral (or Neither, N/A)".

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
sentences = ["VADER is smart, handsome, and funny.",  # positive sentence example
             "VADER is smart, handsome, and funny!",  # punctuation emphasis handled correctly (sentiment intensity adjusted)
             "VADER is very smart, handsome, and funny.", # booster words handled correctly (sentiment intensity adjusted)
             "VADER is VERY SMART, handsome, and FUNNY.",  # emphasis for ALLCAPS handled
             "VADER is VERY SMART, handsome, and FUNNY!!!", # combination of signals - VADER appropriately adjusts intensity
             "VADER is VERY SMART, uber handsome, and FRIGGIN FUNNY!!!", # booster words & punctuation make this close to ceiling for score
             "VADER is not smart, handsome, nor funny.",  # negation sentence example
             "The book was good.",  # positive sentence
             "At least it isn't a horrible book.",  # negated negative sentence with contraction
             "The book was only kind of good.", # qualified positive sentence is handled correctly (intensity adjusted)
             "The plot was good, but the characters are uncompelling and the dialog is not great.", # mixed negation sentence
             "Today SUX!",  # negative slang with capitalization emphasis
             "Today only kinda sux! But I'll get by, lol", # mixed sentiment example with slang and constrastive conjunction "but"
             "Make sure you :) or :D today!",  # emoticons handled
             # "Catch utf-8 emoji such as such as 💘 and 💋 and 😁",  # emojis handled, ignored for seaborn plot below
             "Not bad at all"  # Capitalized negation
             ]

# %%
df_sentiment = []

analyzer = SentimentIntensityAnalyzer()

for sentence in sentences:
    vs = analyzer.polarity_scores(sentence)
    df_sentiment.append(vs)

# %%
df_sentiment = pd.DataFrame(df_sentiment,
                            index = sentences)

# %%
sns.heatmap(df_sentiment, cmap='Blues', annot=True, cbar=False, linewidths=1);

# %% [markdown]
# # EXERCISES

# %% [markdown]
# ## Exercise 1
#
# Using a book from [Project Gutenberg](https://www.gutenberg.org/), get the text data directly from its URL using the `requests` package. Break the book into 50 or more sensible "chunks" like chapters or paragraphs, organizing them into a list.
#
# Load this data into a spaCy pipeline and analyze either Named Entities or Parts of Speech in each chunk.
#
# Provide your analysis: What types of entities or parts of speech are common, and what are uncommon? What insights can you draw from these patterns?
#
# *Note*: Do not download any file, make use of URL in your code.

# %%
# write your code here ...
import requests
import spacy
from collections import Counter

url = "https://www.gutenberg.org/cache/epub/73142/pg73142.txt"
response = requests.get(url)
texts = response.text

# Find the index of "BOYHOOD AND EARLY FLIGHTS"
start_index = texts.find("I was born in Detroit")
# Slicing
texts = texts[start_index:]

nlp = spacy.load('en_core_web_sm')
doc = nlp(texts)
# counter to count the named entity
named_entity_count = Counter()

# Breaking the whole text into 50 sentences
count = 0
for i, sentence in enumerate(doc.sents):
    for ent in sentence.ents:
        named_entity_count[ent.label_] += 1
    print(f"sentence {i+1}\n")
    displacy.render(sentence, style='ent')
    count += 1
    if count == 50:
        break

print("Named Entity Count:")
print(named_entity_count)
# Out:
# sentence 1
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">I was born in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Detroit
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Michigan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     February 4, 1902
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . </div></span>
# sentence 2
# <br>practicing law in
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Little Falls
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Minnesota
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , at the time. </div></span>
# sentence 3
# <br>than
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     two months old
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# <br>banks of
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Mississippi River
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     two miles
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  south of
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Little Falls
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# <br></div></span>
# sentence 4
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">My father,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Charles A. Lindbergh
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , was born in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Stockholm
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sweden
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     January
# 20, 1860
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , the son of
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ola
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Louisa Manson
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# . </div></span>
# sentence 5
# <br>name to
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lindbergh
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  after reaching
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     America
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ) was a member of the
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Swedish
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
# <br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Parliament
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and had at
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# <br></div></span>
# sentence 6
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     About 1860
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# <br>
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     America
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , and settled near
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sauk Center
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Minnesota
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# <br>homestead and built his
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  home in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     America
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# --a log cabin. </div></span>
# sentence 7
# <br></div></span>
# sentence 8
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">The Rev.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     C. S. Harrison
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , writing for
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Minnesota Historical Society
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# <br>gives an account of the activities of my grandfather during
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the early
# days
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Minnesota
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# <br></div></span>
# sentence 9
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">There were very few schools in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Minnesota
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# <br>boyhood
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     days
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  were spent mostly in hunting and fishing. </div></span>
# sentence 10
# <br></div></span>
# sentence 11
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">He was educated at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Grove Lake Academy
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Minnesota
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# <br>the law school at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the University of Michigan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ann Arbor
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# <br></div></span>
# sentence 12
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">He began his law practice in
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Little Falls
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  where he served as
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     County
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# <br>Attorney. </div></span>
# sentence 13
# <br>to the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     60th
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Congress
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1906
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  to represent
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Sixth District
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# <br>
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Minnesota
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  at
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Washington
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , a capacity in which he served for
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ten years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# <br></div></span>
# sentence 14
# <br>FATHER AND
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SON
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# <br></div></span>
# sentence 15
# <br></div></span>
# sentence 16
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">My mother was born in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Detroit
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Michigan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , daughter of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Charles
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# <br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Evangeline Land
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# . </div></span>
# sentence 17
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">She is of
# <mark class="entity" style="background: #ff8197; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     English
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LANGUAGE</span>
# </mark>
# ,
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Irish
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  and
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     French
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  extraction. </div></span>
# sentence 18
# <br>graduate of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the University of Michigan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , she holds a
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     B.S.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# <br>that institution, also an
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     A.M. degree
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  from
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Columbia University
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     New
# York City
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . </div></span>
# sentence 19
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Her father, Dr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Charles H. Land
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , a
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Detroit
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# <br>in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Simcoe
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Norfolk County
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Canada
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , and his father, Colonel
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     John Scott
# Land
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , came from
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     England
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# <br>city of
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hamilton
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# <br></div></span>
# sentence 20
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">My grandfather was constantly experimenting in his laboratory. </div></span>
# sentence 21
# <br>to several on gold and enamel inlays and other dental processes. </div></span>
# sentence 22
# <br>was
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
# <br></div></span>
# sentence 23
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">During
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the first four years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  of my life, I lived in our
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Minnesota
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# <br>with the exception of a few trips to
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Detroit
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . </div></span>
# sentence 24
# <br>elected to
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Congress
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and thereafter I seldom spent more than
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     a few
# months
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  in the same place. </div></span>
# sentence 25
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Our
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     winters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  were passed in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Washington
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# <br>our summers in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Minnesota
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , with intermediate visits to
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Detroit
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# <br></div></span>
# sentence 26
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">When I was
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     eight years of age
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  I entered
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Force School
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Washington
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# <br></div></span>
# sentence 27
# <br>to place. </div></span>
# sentence 28
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Up to the time I entered
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the University of Wisconsin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# <br>never attended for
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one full school year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# <br>from
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     over a dozen
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# <br>
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Washington
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  to
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     California
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# <br></div></span>
# sentence 29
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Through
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     these years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  I crossed and recrossed
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the United States
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , made
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# <br>trip to
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Panama
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# <br></div></span>
# sentence 30
# <br></div></span>
# sentence 31
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Consequently, after graduating from
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Little Falls High School
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# <br>decided to take a course in
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mechanical Engineering
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , and
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     two years later
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# <br>entered
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the College of Engineering of
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the University of Wisconsin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# <br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Madison
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# <br></div></span>
# sentence 32
# <br>in aviation. </div></span>
# sentence 33
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Since I saw my
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  airplane near
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Washington
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# <br>in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1912
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# <br>I enrolled in a flying school in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1922
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# <br></div></span>
# sentence 34
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The long hours
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  of study at college were very trying for me. </div></span>
# sentence 35
# <br></div></span>
# sentence 36
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">At
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wisconsin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# <br>my motorcycle which I had ridden down from
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Minnesota
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# <br></div></span>
# sentence 37
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">I had been raised with a gun on our
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Minnesota
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# <br>place on the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     R.O.T.C.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# <br>
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wisconsin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . </div></span>
# sentence 38
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">From then on I spent
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     every minute
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
# <br></div></span>
# sentence 39
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The first six weeks
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  of vacation after
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     my freshman year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# <br>Artillery School at
# <mark class="entity" style="background: #9cc9cc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Camp Knox
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kentucky
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . </div></span>
# sentence 40
# <br>my motorcycle south and with
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     forty-eight dollars
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# <br>for
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Florida
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . </div></span>
# sentence 41
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">After arriving at
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jacksonville
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  I started back
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the same
# day
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , but over a different route leading farther west than the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
# <br></div></span>
# sentence 42
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Seventeen days
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  after leaving
# <mark class="entity" style="background: #9cc9cc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Camp Knox
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
#  I arrived back in
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Madison
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# <br>motorcycle badly in need of repair and
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     nine dollars
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# <br></div></span>
# sentence 43
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">After stopping in
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Madison
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# <br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Little Falls
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# <br></div></span>
# sentence 44
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Soon after the start of my
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     third
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  semester at
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wisconsin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# <br></div></span>
# sentence 45
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">I remained at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the University of Wisconsin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  long enough to finish
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the
# first half
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  of my sophomore year. </div></span>
# sentence 46
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Then
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     about the end of March, 1922
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# <br>left
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Madison
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  on my motorcycle en route to
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lincoln
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nebraska
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# <br>had enrolled as a flying student with
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Nebraska Aircraft Corporation
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# <br></div></span>
# sentence 47
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">The roads in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wisconsin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     March, 1922
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# <br>after leaving the well-paved highway, I had progressed
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     only about four
# miles
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     as many hours
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
# , I put my motorcycle on the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
# <br>that passed and shipped it to
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lincoln
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# <br></div></span>
# sentence 48
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">I arrived at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lincoln
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the first of April
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . </div></span>
# sentence 49
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">On
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     April 9, 1922
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# <br>my
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  flight as a passenger in a
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lincoln Standard
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  with
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Otto Timm
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# <br>  </div></span>
# sentence 50
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     N. B.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  </div></span>
# Named Entity Count:
# Counter({'GPE': 49, 'DATE': 26, 'ORG': 21, 'PERSON': 19, 'ORDINAL': 8, 'CARDINAL': 5, 'LOC': 3, 'NORP': 3, 'TIME': 3, 'FAC': 2, 'MONEY': 2, 'QUANTITY': 1, 'LANGUAGE': 1})

# %% [markdown]
# ANALYSIS:
# I have sliced the text into sentences, starting from the chapters, as the "content" and "forward" pages of the text didn't look meaningful. I used Named Entity Recognition to count the named entities by their types ('ORGANIZATION', 'PERSON', 'GPE' for geopolitical entities like countries or cities).
#
# We could find that the text contains more number of GPE with a count of 49. This is because, the first chapter focuses on various places that were significant in Charles Lindbergh's early life and aviation endeavors.
#
# subsequently, DATE comes next with a count of 26, as the text explains about the sequence of events, Lindbergh's experiences, and the progression of his interests and activities over time.

# %% [markdown]
# ## Exercise 2
#
# Apply spaCy to extract the most meaningful content from your documents, considering options like excluding stop words or focusing on nouns (i.e. preprocessing and filtering).
#
# Perform a sentiment analysis on the refined data. Create visualization of your result.
#
# Summarize your results by explaining how sentiment changes across sections.

# %% [markdown]
# Below code filters stop words and focuses on NOUNS.

# %%
# write your code here ...
import requests
import spacy


url = "https://www.gutenberg.org/cache/epub/73142/pg73142.txt"
response = requests.get(url)
texts = response.text

# Find the index of "BOYHOOD AND EARLY FLIGHTS"
start_index = texts.find("I was born in Detroit")
# Slicing
texts = texts[start_index:]

nlp = spacy.load('en_core_web_sm')
# Filtering stop words

def Filtering_text(text):
    doc = nlp(text)
    filtered_tokens = [token.text for token in doc if not token.is_stop and token.pos_ == "NOUN" and token.text not in ["SHIPPING", "Illustration","©","_"]]
    return " ".join(filtered_tokens)


filtered_doc = Filtering_text(texts)

# print(filtered_doc)

# %% [markdown]
# Using Sentiment Analysis with VADER, and plotting a Heatmap

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import pandas as pd
import seaborn as sns

count = 0
df_sentiment = []
analyzer = SentimentIntensityAnalyzer()
filtered_doc = nlp(filtered_doc)

for i, sentence in enumerate(filtered_doc.sents):
    print(f"sentence {i+1}\n", sentence)
    sentence_text = sentence.text
    vs = analyzer.polarity_scores(sentence_text)
    df_sentiment.append(vs)
    # to print 5 sentences   
    count += 1
    if count == 7:
        break

# To index sentence numbers
index_labels = [f"sentence - {i}" for i in range(1, len(df_sentiment) + 1)]

df_sentiment = pd.DataFrame(df_sentiment, index=index_labels)
df_sentiment
            

sns.heatmap(df_sentiment, cmap='Blues', annot=True, cbar=False, linewidths=1);
# Out:
# sentence 1
#  father law time months parents farm banks miles father son father member time grandfather family ship homestead home log cabin father life account activities grandfather days schools time father boyhood days hunting fishing education home study term country schools law school degree law practice politics capacity years mother daughter extraction graduate degree institution degree father dentist father founders city grandfather laboratory number patents incandescent grates furnaces addition gold enamel inlays processes possibilities porcelain dentistry father art years life home exception trips father months place winters summers visits years age schooling place place time school year instruction dozen institutions years trip desire travel interest school lines course years aviation airplane time school plane hours study college life time study recreation shooting matches rifle pistol teams motorcycle gun home place teams beginning freshman year minute studies shooting gallery range weeks vacation freshman year motorcycle dollars pocket day route days motorcycle need repair dollars pocket engine remainder vacation start semester aeronautics subject future life work half sophomore year end motorcycle route student roads highway miles hours motorcycle farm wagon rail town flight passenger account period aviation laws existence mind reader experiences incidents book way conditions account events place manner risk pilots members profession exhibition test emergency parachute case plane passengers conditions jump air transport years today stage safety airlines means travel instruction plane days instructor army war months obtaining way flying instruction factory ground school connection course time morning evening account winds midday air student share weather instructor views life morning time instructors student instructor morning end hours instruction addition cost flying course train fare expenses morning president company bond breakage plane result plane months flying course instruction plane trip expenses mechanic helper result towns southeast experience cross country aviator term town flight country fare dollars ride minutes wing walking crowd pasture field town wing tips instruction total hours time world parachute work parachute drop chutes drop parachutes rope canvas bag mouth bag lace bow knot bag way wing plane end plane altitude cockpit wing chute fastens straps harness wing position plane bow knot mouth bag parachute bag wing bow knot bag parachute weight jump parachute rope chute chute weight collapses way jump evening foot altitude field chute seconds second performance tug risers exhibition jump descent seconds head chute time harness position chute vent chute grocery string parachute drop feet opening weeks factory dollars week wire weeks trip need jumper number exhibition contracts capacity fraction cost flying instruction train number exhibitions time time jump wing walking fall wheat rancher plane course corner time land motor trouble herd motor animals picture yards bull foot moment line heads picture time plane trouble
